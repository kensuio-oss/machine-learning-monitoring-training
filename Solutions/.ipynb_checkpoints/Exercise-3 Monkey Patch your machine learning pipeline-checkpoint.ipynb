# %% [markdown]
# # Bank marketing use case |  Monkey Patch your machine learning pipeline
#
# ## 0. Setup

# %%
import sys
sys.path.append("..")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
from utils import data_prep, model_performance, create_observability_report

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
jan = pd.read_csv('../data/predict/jan-data.csv')
model = pickle.load(open('../models/model_log.cav','rb'))

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# You are now aware of the potential datastrophes and failures that may happen in your model pipelines in Production. As a data scientist wanting to have more confidence in those pipelines, you have decided to prevent those failures by logging the events of your scripts.
#
# In this notebook, we will see how a logging library can be included upstream (from the creation of the dataset to the predict of the model) to avoid any datastrophe to happen.

# %% [markdown]
# ## 2. The data extraction script
#
# The logging strategy wants to prevent any failure when you run the model. To be complete, you need to trace and monitor your dataflow as soon as possible. In the following cell, take a moment to acquaint yourself with the code we will run and log in the exercise.

# %%
customers_info = pd.read_csv('../data/predict/may-customers-data.csv')
contact_info = pd.read_csv('../data/predict/may-contact-data.csv')
business_info = pd.read_csv('../data/predict/may-business-data.csv')

customer360 = customers_info.merge(contact_info,on='id')

may = pd.merge(customer360,business_info)

may.to_csv('../data/predict/may-data.csv',index=False)

# %% [markdown]
# ## 3. How to log the events of the script?
#
# In this notebook, we will show you how you can simply log all events in the notebook in order to track the lineage and enable AI observability.
#
# We will use an open source library provided by Kensu. The library will monkey patch the common python libraries such as pandas and sklearn in order to keep records of what happens in the script. With this library, we will be able to extract the following information from the notebook:
# - the data sources used and their schemas
# - the lineages (also named data flow or data map) among those data sources
# - the statistics and metrics of the data sources in that context
#
# To import the library, you need to add the kensu prefix to the library we need to monkeypatch:
#
# $$\text{pandas} \rightarrow  \text{kensu.pandas}$$
#
# Once imported, you can initialize the client with the `KensuProvider` object. Several parameters are available and you can find the list in the user documentation.
#
# The `Context` of the application is defined by its `process_name` (an identifier for your application), `project_names`(where the application is running)

# %%
from kensu.utils.kensu_provider import KensuProvider
kensu = KensuProvider().initKensu(process_name='Exercise 3',
                            user_name='Sammy', 
                            code_location='https://gitlab.example.com', 
                            init_context=True, 
                            project_names=['O-Reilly'], 
                            environment="Production",
                            report_to_file=True,
                            offline_file_name='log_pandas_example.log')

# %% [markdown]
# **Exercise:** Integrate the library in the following code and inspect the result
#
# - *Note:* the client has been already initialized in the previous cell

# %%
#import pandas as pd

import kensu.pandas as pd

customers_info = pd.read_csv('../data/predict/may-customers-data.csv')
contact_info = pd.read_csv('../data/predict/may-contact-data.csv')
business_info = pd.read_csv('../data/predict/may-business-data.csv')

customer360 = customers_info.merge(contact_info,on='id')
may = pd.merge(customer360,business_info)
may.to_csv('../data/predict/may-data.csv',index=False)

# %% [markdown]
# The result of the piece of code you've run is available in the `log_pandas_example.log` file:

# %%
# !cat log_pandas_example.log
# Out:
# {"action": "add_entity", "entity": "PHYSICAL_LOCATION", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "Unknown", "lat": 0.12341234, "lon": 0.12341234, "pk": {"city": "Unknown", "country": "Unknown"}}, "context": {"clientId": "", "clientEventTimestamp": 1619439338936, "serverReceivedTimestamp": 1619439338936}}
# {"action": "add_entity", "entity": "USER", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"name": "Sammy"}}, "context": {"clientId": "", "clientEventTimestamp": 1619439338937, "serverReceivedTimestamp": 1619439338937}}
# {"action": "add_entity", "entity": "CODE_BASE", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"location": "https://gitlab.example.com"}}, "context": {"clientId": "", "clientEventTimestamp": 1619439338937, "serverReceivedTimestamp": 1619439338937}}
# {"action": "add_entity", "entity": "CODE_VERSION", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"version": "2021-04-26T14:15:38.935803", "codebaseRef": {"byGUID": "k-261982ef6bd2fa29a51fb40e4b5ed82e9d6a12abb736963747ac07d804d91541"}}, "maintainersRefs": [{"byGUID": "k-3b03f67dc7e25fbcf60115a3a5fd3b15ecbcb68348590b00f1806af018a61f8b"}]}, "context": {"clientId": "", "clientEventTimestamp": 1619439338937, "serverReceivedTimestamp": 1619439338937}}
# {"action": "add_entity", "entity": "PROCESS", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"qualifiedName": "Exercise 3"}}, "context": {"clientId": "", "clientEventTimestamp": 1619439338937, "serverReceivedTimestamp": 1619439338937}}
# {"action": "add_entity", "entity": "PROJECT", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"name": "O-Reilly"}}, "context": {"clientId": "", "clientEventTimestamp": 1619439338937, "serverReceivedTimestamp": 1619439338937}}
# {"action": "add_entity", "entity": "PROCESS_RUN", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"processRef": {"byGUID": "k-b2493e679852562738dcb9a32aea427d81179bb34a9f9b4beb56db23eabc0e25"}, "qualifiedName": "Exercise 3@2021-04-26T14:15:38.936909"}, "launchedByUserRef": {"byGUID": "k-3b03f67dc7e25fbcf60115a3a5fd3b15ecbcb68348590b00f1806af018a61f8b"}, "executedCodeVersionRef": {"byGUID": "k-28c696809b5e8d7fc2b8c52cfd7bf13afc190bd3a19a5e94ead3eedf03a93940"}, "environment": "Production", "projectsRefs": [{"byGUID": "k-1ca8ef8f92194cae735cedb346749fe39fcb032884aa5d3cdd5871af20d6dca3"}]}, "context": {"clientId": "", "clientEventTimestamp": 1619439338937, "serverReceivedTimestamp": 1619439338937}}
# {"action": "add_entity", "entity": "DATA_SOURCE", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "predict/may-customers-data.csv", "format": "csv", "categories": [], "pk": {"location": "file:/Users/kensu/Customers/Kensu/AI_obs_training/data/predict/may-customers-data.csv", "physicalLocationRef": {"byGUID": "k-b951826eab16e342d6e6575de63aed5624d3342b6ee670313f80782ecaa3f08e"}}}, "context": {"clientId": "", "clientEventTimestamp": 1619439338986, "serverReceivedTimestamp": 1619439338986}}
# {"action": "add_entity", "entity": "SCHEMA", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "schema:predict/may-customers-data.csv", "pk": {"dataSourceRef": {"byGUID": "k-4e1451bed1ea55b4967aa5d2f641ff65a9ffaa078d43a3e7244a0a7ff45716cd"}, "fields": [{"name": "age", "fieldType": "int64", "nullable": true}, {"name": "job", "fieldType": "object", "nullable": true}, {"name": "marital", "fieldType": "object", "nullable": true}, {"name": "education", "fieldType": "object", "nullable": true}, {"name": "default", "fieldType": "object", "nullable": true}, {"name": "housing", "fieldType": "object", "nullable": true}, {"name": "loan", "fieldType": "object", "nullable": true}, {"name": "id", "fieldType": "int64", "nullable": true}]}}, "context": {"clientId": "", "clientEventTimestamp": 1619439338987, "serverReceivedTimestamp": 1619439338987}}
# {"action": "add_entity", "entity": "DATA_SOURCE", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "predict/may-contact-data.csv", "format": "csv", "categories": [], "pk": {"location": "file:/Users/kensu/Customers/Kensu/AI_obs_training/data/predict/may-contact-data.csv", "physicalLocationRef": {"byGUID": "k-b951826eab16e342d6e6575de63aed5624d3342b6ee670313f80782ecaa3f08e"}}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339037, "serverReceivedTimestamp": 1619439339037}}
# {"action": "add_entity", "entity": "SCHEMA", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "schema:predict/may-contact-data.csv", "pk": {"dataSourceRef": {"byGUID": "k-5faff3a786cf63312064ee13c0fa35f5586db9a0c3702f699f97d563c96fe4be"}, "fields": [{"name": "contact", "fieldType": "object", "nullable": true}, {"name": "month", "fieldType": "object", "nullable": true}, {"name": "day_of_week", "fieldType": "object", "nullable": true}, {"name": "duration", "fieldType": "int64", "nullable": true}, {"name": "campaign", "fieldType": "int64", "nullable": true}, {"name": "pdays", "fieldType": "int64", "nullable": true}, {"name": "previous", "fieldType": "int64", "nullable": true}, {"name": "poutcome", "fieldType": "object", "nullable": true}, {"name": "id", "fieldType": "int64", "nullable": true}]}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339038, "serverReceivedTimestamp": 1619439339038}}
# {"action": "add_entity", "entity": "DATA_SOURCE", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "predict/may-business-data.csv", "format": "csv", "categories": [], "pk": {"location": "file:/Users/kensu/Customers/Kensu/AI_obs_training/data/predict/may-business-data.csv", "physicalLocationRef": {"byGUID": "k-b951826eab16e342d6e6575de63aed5624d3342b6ee670313f80782ecaa3f08e"}}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339081, "serverReceivedTimestamp": 1619439339081}}
# {"action": "add_entity", "entity": "SCHEMA", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "schema:predict/may-business-data.csv", "pk": {"dataSourceRef": {"byGUID": "k-1e88190a34d2b3115829dc74c9a4180438e6e69be44f0f2f9634c995b3d023e0"}, "fields": [{"name": "emp_var_rate", "fieldType": "float64", "nullable": true}, {"name": "cons_price_idx", "fieldType": "float64", "nullable": true}, {"name": "cons_conf_idx", "fieldType": "float64", "nullable": true}, {"name": "euribor3m", "fieldType": "float64", "nullable": true}, {"name": "nr_employed", "fieldType": "float64", "nullable": true}, {"name": "id", "fieldType": "int64", "nullable": true}]}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339082, "serverReceivedTimestamp": 1619439339082}}
# {"action": "add_entity", "entity": "DATA_SOURCE", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "predict/may-data.csv", "format": "csv", "categories": [], "pk": {"location": "file:/Users/kensu/Customers/Kensu/AI_obs_training/data/predict/may-data.csv", "physicalLocationRef": {"byGUID": "k-b951826eab16e342d6e6575de63aed5624d3342b6ee670313f80782ecaa3f08e"}}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339508, "serverReceivedTimestamp": 1619439339508}}
# {"action": "add_entity", "entity": "SCHEMA", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "schema:predict/may-data.csv", "pk": {"dataSourceRef": {"byGUID": "k-d1229e1b0685e46685a5758ec531a8eb38bcb19b68e238946187ed4150e10716"}, "fields": [{"name": "age", "fieldType": "int64", "nullable": true}, {"name": "job", "fieldType": "object", "nullable": true}, {"name": "marital", "fieldType": "object", "nullable": true}, {"name": "education", "fieldType": "object", "nullable": true}, {"name": "default", "fieldType": "object", "nullable": true}, {"name": "housing", "fieldType": "object", "nullable": true}, {"name": "loan", "fieldType": "object", "nullable": true}, {"name": "id", "fieldType": "int64", "nullable": true}, {"name": "contact", "fieldType": "object", "nullable": true}, {"name": "month", "fieldType": "object", "nullable": true}, {"name": "day_of_week", "fieldType": "object", "nullable": true}, {"name": "duration", "fieldType": "int64", "nullable": true}, {"name": "campaign", "fieldType": "int64", "nullable": true}, {"name": "pdays", "fieldType": "int64", "nullable": true}, {"name": "previous", "fieldType": "int64", "nullable": true}, {"name": "poutcome", "fieldType": "object", "nullable": true}, {"name": "emp_var_rate", "fieldType": "float64", "nullable": true}, {"name": "cons_price_idx", "fieldType": "float64", "nullable": true}, {"name": "cons_conf_idx", "fieldType": "float64", "nullable": true}, {"name": "euribor3m", "fieldType": "float64", "nullable": true}, {"name": "nr_employed", "fieldType": "float64", "nullable": true}]}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339508, "serverReceivedTimestamp": 1619439339508}}
# {"action": "add_entity", "entity": "PROCESS_LINEAGE", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"name": "Lineage to k-411e128eb658022229b433e2bab818bcdf447e2751fe10e73aaae87c3bdf1b00 from k-3ecc69e299ae0848e562cc96b0b6bc34a2538b8817b32ae63bb37849177278a2,k-c324907f10dd4da4938bba7a8f8673b8433550a408f2ef22d1522184d80f39a5,k-197d11b5fea3956e2d459c37409bf326a0998acf6700d06e15fb74e8f50bf6b4", "operationLogic": "APPEND", "pk": {"processRef": {"byGUID": "k-b2493e679852562738dcb9a32aea427d81179bb34a9f9b4beb56db23eabc0e25"}, "dataFlow": [{"fromSchemaRef": {"byGUID": "k-c324907f10dd4da4938bba7a8f8673b8433550a408f2ef22d1522184d80f39a5"}, "toSchemaRef": {"byGUID": "k-411e128eb658022229b433e2bab818bcdf447e2751fe10e73aaae87c3bdf1b00"}, "columnDataDependencies": {"age": ["age"], "default": ["default"], "education": ["education"], "housing": ["housing"], "id": ["id"], "job": ["job"], "loan": ["loan"], "marital": ["marital"]}}, {"fromSchemaRef": {"byGUID": "k-197d11b5fea3956e2d459c37409bf326a0998acf6700d06e15fb74e8f50bf6b4"}, "toSchemaRef": {"byGUID": "k-411e128eb658022229b433e2bab818bcdf447e2751fe10e73aaae87c3bdf1b00"}, "columnDataDependencies": {"campaign": ["campaign"], "contact": ["contact"], "day_of_week": ["day_of_week"], "duration": ["duration"], "id": ["id"], "month": ["month"], "pdays": ["pdays"], "poutcome": ["poutcome"], "previous": ["previous"]}}, {"fromSchemaRef": {"byGUID": "k-3ecc69e299ae0848e562cc96b0b6bc34a2538b8817b32ae63bb37849177278a2"}, "toSchemaRef": {"byGUID": "k-411e128eb658022229b433e2bab818bcdf447e2751fe10e73aaae87c3bdf1b00"}, "columnDataDependencies": {"cons_conf_idx": ["cons_conf_idx"], "cons_price_idx": ["cons_price_idx"], "emp_var_rate": ["emp_var_rate"], "euribor3m": ["euribor3m"], "nr_employed": ["nr_employed"]}}]}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339622, "serverReceivedTimestamp": 1619439339622}}
# {"action": "add_entity", "entity": "LINEAGE_RUN", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"processRunRef": {"byGUID": "k-1c914311429f368c6808951a275f18b2cadcf02e3aecec45e578d53c42d2dac9"}, "lineageRef": {"byGUID": "k-0e251e97d910ea2eee090f56d4041592ef150fdf7eaa6ec61dcd76ed3f445c82"}, "timestamp": 1619439338936}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339622, "serverReceivedTimestamp": 1619439339622}}
# {"action": "add_entity", "entity": "DATA_STATS", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"schemaRef": {"byGUID": "k-411e128eb658022229b433e2bab818bcdf447e2751fe10e73aaae87c3bdf1b00"}, "lineageRunRef": {"byGUID": "k-915f724b3b18e3d3257db16c6ab1d700e07cf9dcaa86a88dc0248fe181d4eae6"}}, "stats": {"age.count": 8203.0, "age.mean": 40.021089845178594, "age.std": 10.359799770608443, "age.min": 17.0, "age.25%": 32.0, "age.50%": 38.0, "age.75%": 47.0, "age.max": 92.0, "id.count": 8203.0, "id.mean": 20800.505668657806, "id.std": 11912.35444786826, "id.min": 0.0, "id.25%": 10489.0, "id.50%": 20851.0, "id.75%": 31190.5, "id.max": 41181.0, "duration.count": 8203.0, "duration.mean": 258.7276606119712, "duration.std": 257.2433339173094, "duration.min": 2.0, "duration.25%": 103.0, "duration.50%": 181.0, "duration.75%": 317.0, "duration.max": 3322.0, "campaign.count": 8203.0, "campaign.mean": 2.5323662074850666, "campaign.std": 2.7049079989166644, "campaign.min": 1.0, "campaign.25%": 1.0, "campaign.50%": 2.0, "campaign.75%": 3.0, "campaign.max": 56.0, "pdays.count": 8203.0, "pdays.mean": 965.5872241862733, "pdays.std": 179.07795227120567, "pdays.min": 0.0, "pdays.25%": 999.0, "pdays.50%": 999.0, "pdays.75%": 999.0, "pdays.max": 999.0, "previous.count": 8203.0, "previous.mean": 0.1684749481896867, "previous.std": 0.49072942110753165, "previous.min": 0.0, "previous.25%": 0.0, "previous.50%": 0.0, "previous.75%": 0.0, "previous.max": 7.0, "emp_var_rate.count": 8203.0, "emp_var_rate.mean": 0.08349384371571376, "emp_var_rate.std": 1.5598482889437482, "emp_var_rate.min": -3.4, "emp_var_rate.25%": -1.8, "emp_var_rate.50%": 1.1, "emp_var_rate.75%": 1.4, "emp_var_rate.max": 1.4, "cons_price_idx.count": 8203.0, "cons_price_idx.mean": 93.57722528343288, "cons_price_idx.std": 0.5738868798808014, "cons_price_idx.min": 92.20100000000001, "cons_price_idx.25%": 93.075, "cons_price_idx.50%": 93.79799999999999, "cons_price_idx.75%": 93.994, "cons_price_idx.max": 94.76700000000001, "cons_conf_idx.count": 8203.0, "cons_conf_idx.mean": -40.5384981104474, "cons_conf_idx.std": 4.616099419146233, "cons_conf_idx.min": -50.8, "cons_conf_idx.25%": -42.7, "cons_conf_idx.50%": -41.8, "cons_conf_idx.75%": -36.4, "cons_conf_idx.max": -26.9, "euribor3m.count": 8203.0, "euribor3m.mean": 3.615791783493844, "euribor3m.std": 1.7360513862075226, "euribor3m.min": 0.634, "euribor3m.25%": 1.344, "euribor3m.50%": 4.857, "euribor3m.75%": 4.961, "euribor3m.max": 5.045, "nr_employed.count": 8203.0, "nr_employed.mean": 5166.56903571864, "nr_employed.std": 72.51525927677316, "nr_employed.min": 4963.6, "nr_employed.25%": 5099.1, "nr_employed.50%": 5191.0, "nr_employed.75%": 5228.1, "nr_employed.max": 5228.1}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339661, "serverReceivedTimestamp": 1619439339661}}
# {"action": "add_entity", "entity": "DATA_STATS", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"schemaRef": {"byGUID": "k-3ecc69e299ae0848e562cc96b0b6bc34a2538b8817b32ae63bb37849177278a2"}, "lineageRunRef": {"byGUID": "k-915f724b3b18e3d3257db16c6ab1d700e07cf9dcaa86a88dc0248fe181d4eae6"}}, "stats": {"emp_var_rate.count": 8203.0, "emp_var_rate.mean": 0.08349384371571376, "emp_var_rate.std": 1.5598482889437482, "emp_var_rate.min": -3.4, "emp_var_rate.25%": -1.8, "emp_var_rate.50%": 1.1, "emp_var_rate.75%": 1.4, "emp_var_rate.max": 1.4, "cons_price_idx.count": 8203.0, "cons_price_idx.mean": 93.57722528343288, "cons_price_idx.std": 0.5738868798808014, "cons_price_idx.min": 92.20100000000001, "cons_price_idx.25%": 93.075, "cons_price_idx.50%": 93.79799999999999, "cons_price_idx.75%": 93.994, "cons_price_idx.max": 94.76700000000001, "cons_conf_idx.count": 8203.0, "cons_conf_idx.mean": -40.5384981104474, "cons_conf_idx.std": 4.616099419146233, "cons_conf_idx.min": -50.8, "cons_conf_idx.25%": -42.7, "cons_conf_idx.50%": -41.8, "cons_conf_idx.75%": -36.4, "cons_conf_idx.max": -26.9, "euribor3m.count": 8203.0, "euribor3m.mean": 3.615791783493844, "euribor3m.std": 1.7360513862075226, "euribor3m.min": 0.634, "euribor3m.25%": 1.344, "euribor3m.50%": 4.857, "euribor3m.75%": 4.961, "euribor3m.max": 5.045, "nr_employed.count": 8203.0, "nr_employed.mean": 5166.56903571864, "nr_employed.std": 72.51525927677316, "nr_employed.min": 4963.6, "nr_employed.25%": 5099.1, "nr_employed.50%": 5191.0, "nr_employed.75%": 5228.1, "nr_employed.max": 5228.1, "id.count": 8203.0, "id.mean": 20800.505668657806, "id.std": 11912.35444786826, "id.min": 0.0, "id.25%": 10489.0, "id.50%": 20851.0, "id.75%": 31190.5, "id.max": 41181.0}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339680, "serverReceivedTimestamp": 1619439339680}}
# {"action": "add_entity", "entity": "DATA_STATS", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"schemaRef": {"byGUID": "k-c324907f10dd4da4938bba7a8f8673b8433550a408f2ef22d1522184d80f39a5"}, "lineageRunRef": {"byGUID": "k-915f724b3b18e3d3257db16c6ab1d700e07cf9dcaa86a88dc0248fe181d4eae6"}}, "stats": {"age.count": 8203.0, "age.mean": 40.021089845178594, "age.std": 10.359799770608443, "age.min": 17.0, "age.25%": 32.0, "age.50%": 38.0, "age.75%": 47.0, "age.max": 92.0, "id.count": 8203.0, "id.mean": 20800.505668657806, "id.std": 11912.35444786826, "id.min": 0.0, "id.25%": 10489.0, "id.50%": 20851.0, "id.75%": 31190.5, "id.max": 41181.0}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339687, "serverReceivedTimestamp": 1619439339687}}
# {"action": "add_entity", "entity": "DATA_STATS", "generatedEntityGUID": "empty", "schemaVersion": "0.1", "jsonPayload": {"pk": {"schemaRef": {"byGUID": "k-197d11b5fea3956e2d459c37409bf326a0998acf6700d06e15fb74e8f50bf6b4"}, "lineageRunRef": {"byGUID": "k-915f724b3b18e3d3257db16c6ab1d700e07cf9dcaa86a88dc0248fe181d4eae6"}}, "stats": {"duration.count": 8203.0, "duration.mean": 258.7276606119712, "duration.std": 257.2433339173094, "duration.min": 2.0, "duration.25%": 103.0, "duration.50%": 181.0, "duration.75%": 317.0, "duration.max": 3322.0, "campaign.count": 8203.0, "campaign.mean": 2.5323662074850666, "campaign.std": 2.7049079989166644, "campaign.min": 1.0, "campaign.25%": 1.0, "campaign.50%": 2.0, "campaign.75%": 3.0, "campaign.max": 56.0, "pdays.count": 8203.0, "pdays.mean": 965.5872241862733, "pdays.std": 179.07795227120567, "pdays.min": 0.0, "pdays.25%": 999.0, "pdays.50%": 999.0, "pdays.75%": 999.0, "pdays.max": 999.0, "previous.count": 8203.0, "previous.mean": 0.1684749481896867, "previous.std": 0.49072942110753165, "previous.min": 0.0, "previous.25%": 0.0, "previous.50%": 0.0, "previous.75%": 0.0, "previous.max": 7.0, "id.count": 8203.0, "id.mean": 20800.505668657806, "id.std": 11912.35444786826, "id.min": 0.0, "id.25%": 10489.0, "id.50%": 20851.0, "id.75%": 31190.5, "id.max": 41181.0}}, "context": {"clientId": "", "clientEventTimestamp": 1619439339703, "serverReceivedTimestamp": 1619439339703}}

# %% [markdown]
# This file is not easy to understand by itself. Fortunately, the `create_observability_report` function from the utils module will help you to generate documentation based on the log file.
#
# The function takes 2 arguments, the first one is the `log file` path, and the second is the name of the document with a `.pdf` extention that you want to generate.

# %%
create_observability_report('log_pandas_example.log','Report-example.pdf')

# %% [markdown]
# ## Well done!
#
# A new observability report is now available in your working directory. Take a moment to explore it. What more would you like to log?
#
# In the next exercise, we will see how you can activate those reports in order to have SLA and SLO in your AI pipelines.
